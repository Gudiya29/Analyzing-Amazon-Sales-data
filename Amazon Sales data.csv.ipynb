# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import seaborn as sns

# %%
df = pd.read_csv('Amazon Sales data.csv')

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933  6/27/2010        9925
# 1        Online              C 2012-08-22  963881480  9/15/2012        2804
# 2       Offline              L 2014-05-02  341417157   5/8/2014        1779
# 3        Online              C 2014-06-20  514321792   7/5/2014        8102
# 4       Offline              L 2013-02-01  115456712   2/6/2013        5062
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  Year  \
# 0      255.28     159.42     2533654.00  1582243.50     951410.50  2010
# 1      205.70     117.11      576782.80   328376.44     248406.36  2012
# 2      651.21     524.96     1158502.59   933903.84     224598.75  2014
# 3        9.33       6.92       75591.66    56065.84      19525.82  2014
# 4      651.21     524.96     3296425.02  2657347.52     639077.50  2013
#
#    Month  Day
# 0      5   28
# 1      8   22
# 2      5    2
# 3      6   20
# 4      2    1

# %%
df['Order ID'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Order ID, Length: 100, dtype: bool

# %%
df.drop_duplicates('Order ID')
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
#    Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Offline              H 2010-05-28  669165933   6/27/2010        9925
# 1         Online              C 2012-08-22  963881480   9/15/2012        2804
# 2        Offline              L 2014-05-02  341417157    5/8/2014        1779
# 3         Online              C 2014-06-20  514321792    7/5/2014        8102
# 4        Offline              L 2013-02-01  115456712    2/6/2013        5062
# ..           ...            ...        ...        ...         ...         ...
# 95        Online              M 2011-07-26  512878119    9/3/2011         888
# 96       Offline              L 2011-11-11  810711038  12/28/2011        6267
# 97       Offline              C 2016-06-01  728815257   6/29/2016        1485
# 98       Offline              M 2015-07-30  559427106    8/8/2015        5767
# 99       Offline              L 2012-02-10  665095412   2/15/2012        5367
#
#     Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  Year  \
# 0       255.28     159.42     2533654.00  1582243.50     951410.50  2010
# 1       205.70     117.11      576782.80   328376.44     248406.36  2012
# 2       651.21     524.96     1158502.59   933903.84     224598.75  2014
# 3         9.33       6.92       75591.66    56065.84      19525.82  2014
# 4       651.21     524.96     3296425.02  2657347.52     639077.50  2013
# ..         ...        ...            ...         ...           ...   ...
# 95      109.28      35.84       97040.64    31825.92      65214.72  2011
# 96        9.33       6.92       58471.11    43367.64      15103.47  2011
# 97      154.06      90.93      228779.10   135031.05      93748.05  2016
# 98       81.73      56.67      471336.91   326815.89     144521.02  2015
# 99      668.27     502.54     3586605.09  2697132.18     889472.91  2012
#
#     Month  Day
# 0       5   28
# 1       8   22
# 2       5    2
# 3       6   20
# 4       2    1
# ..    ...  ...
# 95      7   26
# 96     11   11
# 97      6    1
# 98      7   30
# 99      2   10
#
# [100 rows x 17 columns]

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit         Year       Month         Day
# count  1.000000e+02  1.000000e+02   100.000000  100.000000  100.000000
# mean   9.318057e+05  4.416820e+05  2013.230000    6.260000   16.500000
# std    1.083938e+06  4.385379e+05     2.088231    3.353334    8.997755
# min    3.612240e+03  1.258020e+03  2010.000000    1.000000    1.000000
# 25%    1.688680e+05  1.214436e+05  2012.000000    4.000000    8.000000
# 50%    3.635664e+05  2.907680e+05  2013.000000    6.000000   17.000000
# 75%    1.613870e+06  6.358288e+05  2015.000000    9.250000   24.250000
# max    4.509794e+06  1.719922e+06  2017.000000   12.000000   31.000000

# %%
sns.histplot(x='Order Date',data=df,kde=True,color='Orange')
# Out:
# <AxesSubplot:xlabel='Order Date', ylabel='Count'>

# %%
sns.histplot(x='Total Revenue', data=df, hue='Sales Channel', element='poly')
# Out:
# <AxesSubplot:xlabel='Total Revenue', ylabel='Count'>

# %%
sns.barplot(y='Region',x='Units Sold',data=df,palette='CMRmap')
# Out:
# <AxesSubplot:xlabel='Units Sold', ylabel='Region'>

# %%
sns.histplot(x='Total Profit', data=df, hue='Item Type')
# Out:
# <AxesSubplot:xlabel='Total Profit', ylabel='Count'>

# %%
sns.boxplot(x='Order Priority', y='Total Profit', data=df, color='pink', linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='Order Priority', ylabel='Total Profit'>

# %%
sns.barplot(x='Unit Cost', y='Item Type', data=df, palette='CMRmap')
# Out:
# <AxesSubplot:xlabel='Unit Cost', ylabel='Item Type'>

# %%
sns.histplot(y='Order Date',hue='Region',data=df)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Order Date'>

# %%
sns.lineplot(x='Order Date', y='Total Profit', data=df, marker='o', color='black')
sns.set(rc={'figure.figsize':(15,5)})
plt.title('Year on Year Growth',fontsize=30)
plt.xlabel('Order Year',fontsize=25)
plt.ylabel('Total Profit',fontsize=25)
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
sns.barplot(x='Region', y='Total Profit', data=df, palette='cividis', ci=None)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Total Profit'>
